# %% [markdown]
# <a href="https://colab.research.google.com/github/liormedan/MYSLACK/blob/main/vtext_stt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **התקנת המודל**

# %%
# התקנת הספרייה
# !pip install google-cloud-speech

# ייבוא הספריות
import os
from google.cloud import speech_v1p1beta1 as speech
from google.colab import files

# העלאת קובץ הקרדינטיאלים
credentials_upload = files.upload()
credentials_file = list(credentials_upload.keys())[0]
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = credentials_file

# העלאת הקובץ הקולי
audio_upload = files.upload()
audio_file = list(audio_upload.keys())[0]

# ביצוע הזיהוי
client = speech.SpeechClient()

audio = speech.RecognitionAudio(content=audio_upload[audio_file])
config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.MP3,
    sample_rate_hertz=16000,
    language_code="en-US",
)

response = client.recognize(config=config, audio=audio)

# קריאת התוצאות
for result in response.results:
    print("Transcript: {}".format(result.alternatives[0].transcript))
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.2/275.2 kB 5.0 MB/s eta 0:00:00
# ...
#      <input type="file" id="files-24e53e7c-45a7-424a-a179-e938cd7e5a41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24e53e7c-45a7-424a-a179-e938cd7e5a41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
